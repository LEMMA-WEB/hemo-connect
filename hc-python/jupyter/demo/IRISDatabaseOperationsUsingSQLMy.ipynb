# %% [markdown]
# # Helpful links:
# Database connection:
# https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=BPYNAT_pyapi
#
# SQL:
# https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=RSQL_createtable
#
# Data Types:
# https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=RSQL_datatype

# %% [markdown]
# # Loading the data to a dataframe
# This tutorial covers how to use IRIS as a vector database.
#
# For this tutorial, we will use a dataset of 2.2k online reviews of scotch (
# dataset from https://www.kaggle.com/datasets/koki25ando/22000-scotch-whisky-reviews) . With our latest vector database functionality, we can leverage the latest embedding models to run semantic search on the online reviews of scotch whiskeys. In addition, we'll be able to apply filters on columns with structured data. For example, we will be able to search for whiskeys that are priced under $100, and are 'earthy, smooth, and easy to drink'. Let's find our perfect whiskey!

# %%
import pandas as pd
import csv


# Load the CSV file
df = pd.read_csv('../data/B-IHOK-AH_AMB-FINAL.csv', sep="|", on_bad_lines="skip")

# View the data
df.head()
# Out:
#    ic_amb_zad  ic_amb_karta   ic_pac     dat_zad   cas_zad  prac_od dg_kod  \
# 0    25775488       3702287   257353  2023-01-09  14:47:00    41742    NaN
# 1    26043815       4712677  1773067  2023-01-09  13:11:00    41742    NaN
# 2    26015332       2480460     3436  2023-01-09  15:06:00    41742    NaN
# 3    25567942       5809559  2135408  2023-01-09  15:04:00    41742    NaN
# 4    25833197       6059137    86335  2023-01-09  15:09:00    41742    NaN
#
#   i_dg_kod                                            text_dg  \
# 0    C911                                                 NaN
# 1    C911   calquence                                     ...
# 2    C911   venetoklax příjem IHOK                        ...
# 3    C911   kontrola                                      ...
# 4    C911   imbruvica                                     ...
#
#                                            i_text_dg poz_text  \
# 0  Chronická lymfocytická leukemie z B-buněk     ...      NaN
# 1  Chronická lymfocytická leukemie z B-buněk     ...      NaN
# 2  Chronická lymfocytická leukemie z B-buněk     ...      NaN
# 3  Chronická lymfocytická leukemie z B-buněk     ...      NaN
# 4  Chronická lymfocytická leukemie z B-buněk     ...      NaN
#
#                                         amb_zaz_text
# 0  Odběr:09.01.2023 10:53 -----------------------...
# 1  Počátek vyšetření: 09.01.2023 12:53 Odběr:09.0...
# 2  studie LOXO 20022, pacient číslo 2201-440 plat...
# 3  Počátek vyšetření: 09.01.2023 14:39 Odběr:09.0...
# 4  Odběr:09.01.2023 10:54 -----------------------...

# %%
# Clean data
# Remove the specified columns
#df.drop(['currency'], axis=1, inplace=True)

# Drop the first column
#df.drop(columns=df.columns[0], inplace=True)

# Remove rows without a price
#df.dropna(subset=['price'], inplace=True)

# Ensure values in 'price' are numbers
#df = df[pd.to_numeric(df['price'], errors='coerce').notna()]

# Replace NaN values in other columns with an empty string
df.fillna('', inplace=True)
df.truncate()

# View cleaned data
df.head()
# Out:
#    ic_amb_zad  ic_amb_karta   ic_pac     dat_zad   cas_zad  prac_od dg_kod  \
# 0    25775488       3702287   257353  2023-01-09  14:47:00    41742
# 1    26043815       4712677  1773067  2023-01-09  13:11:00    41742
# 2    26015332       2480460     3436  2023-01-09  15:06:00    41742
# 3    25567942       5809559  2135408  2023-01-09  15:04:00    41742
# 4    25833197       6059137    86335  2023-01-09  15:09:00    41742
#
#   i_dg_kod                                            text_dg  \
# 0    C911
# 1    C911   calquence                                     ...
# 2    C911   venetoklax příjem IHOK                        ...
# 3    C911   kontrola                                      ...
# 4    C911   imbruvica                                     ...
#
#                                            i_text_dg poz_text  \
# 0  Chronická lymfocytická leukemie z B-buněk     ...
# 1  Chronická lymfocytická leukemie z B-buněk     ...
# 2  Chronická lymfocytická leukemie z B-buněk     ...
# 3  Chronická lymfocytická leukemie z B-buněk     ...
# 4  Chronická lymfocytická leukemie z B-buněk     ...
#
#                                         amb_zaz_text
# 0  Odběr:09.01.2023 10:53 -----------------------...
# 1  Počátek vyšetření: 09.01.2023 12:53 Odběr:09.0...
# 2  studie LOXO 20022, pacient číslo 2201-440 plat...
# 3  Počátek vyšetření: 09.01.2023 14:39 Odběr:09.0...
# 4  Odběr:09.01.2023 10:54 -----------------------...

# %% [markdown]
# # IRIS database operations

# %%
import iris
import time
import os

# %% [markdown]
# ## Database connection settings

# %%
username = 'demo'
password = 'demo'
hostname = os.getenv('IRIS_HOSTNAME', 'localhost')
port = '1972' 
namespace = 'USER'
CONNECTION_STRING = f"{hostname}:{port}/{namespace}"

# %%
print(CONNECTION_STRING)
# Out:
# localhost:1972/USER

# %%
# Note: Ideally conn and cursor should be used with context manager or with try-execpt-finally 
conn = iris.connect(CONNECTION_STRING, username, password)
cursor = conn.cursor()

# %% [markdown]
# ## Creating a new table

# %%
tableName = "SchemaName.TableName"
tableDefinition = """(ic_amb_zad INT, ic_amb_karta INT, ic_pac INT, 
                    dat_zad DATE, cas_zad TIME, prac_od INT, dg_kod MEDIUMTEXT, i_dg_kod MEDIUMTEXT, 
                    text_dg MEDIUMTEXT, i_text_dg MEDIUMTEXT, poz_text MEDIUMTEXT, amb_zaz_text LONGTEXT)"""

# %%
try:
    cursor.execute(f"DROP TABLE {tableName}")  
except:
    pass
cursor.execute(f"CREATE TABLE {tableName} {tableDefinition}")
# Out:
# 0

# %% [markdown]
# This created table can be viewed by going to the IRIS management portal at: http://localhost:52773/csp/sys/UtilHome.csp
#
# Note: When you create a table and specify the desired data fields, a RowID field is automatically created
# https://docs.intersystems.com/irisforhealthlatest/csp/docbook/DocBook.UI.Page.cls?KEY=GSQL_tables#GSQL_tables_idfield

# %% [markdown]
# ## Deleting rows

# %%
sql = f"DELETE FROM {tableName} WHERE ID = 1"
cursor.execute(sql)
# Out:
# 0

# %% [markdown]
# ## Adding data one row at a time by looping over the dataframe

# %%
try:
    cursor.execute(f"DROP TABLE {tableName}")  
except:
    pass
cursor.execute(f"CREATE TABLE {tableName} {tableDefinition}")
# Out:
# 0

# %%
##looping through dataframe and adding all the data to IRIS table
sql = f"""Insert into {tableName} (ic_amb_zad, ic_amb_karta, ic_pac, 
                    dat_zad, cas_zad, prac_od, dg_kod, i_dg_kod, 
                    text_dg, i_text_dg, poz_text, amb_zaz_text) values (?,?,?,?,?,?,?,?,?,?,?,?)"""
start_time = time.time()
for index,row in df.iterrows():
    data = (row['ic_amb_zad'], row['ic_amb_karta'], row['ic_pac'], row['dat_zad'], row['cas_zad'], row['prac_od'], row['dg_kod'], row['i_dg_kod'], row['text_dg'], row['i_text_dg'], row['poz_text'], row['amb_zaz_text'])
    cursor.execute(sql, data)
end_time = time.time()
print(f"time taken to add {len(df)} entries: {end_time-start_time} seconds")
# Out:
# time taken to add 5572 entries: 2.522099256515503 seconds

# %% [markdown]
# ## Reading from the table

# %%
## Read only select columns
cursor.execute(f"select * from {tableName}")
fetched_data = cursor.fetchmany(3)
for row in fetched_data:
    print(row)
# Out:
# (25775488, 3702287, 257353, datetime.date(2023, 1, 9), datetime.time(14, 47), 41742, '', 'C911 ', '', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'Odběr:09.01.2023 10:53 ------------------------------------------------------------  Ret% 1.67 %   Reta 59.50 10^9/l   IRF 0.258    RET-He 35.3 pg   WBC 27.700 10^9/l   RBC 3.56 10^12/l   HGB 122.0 g/l   HCT 0.360 l/l MCV 101.7 fL   PLT 129.0 10^9/l   MCH 34.3 pg   MCHC 337.0 g/l   MPV 9.30 fl   RDW 14.2 %   NEU% 1.60 %   LYM% 94.40 %   MON% 3.40 % EOS% 0.30 %   BAS% 0.30 %   NEU 0.480 10^9/l   LYM 26.150 10^9/l MONO 0.930 10^9/l   EOS 0.070 10^9/l   BASO 0.070 10^9/l   NRBC 0.04 Odběr:09.01.2023 10:52 Urea S-Urea 5.5 mmol/l  (2.8-8.1) Kreat. S-Kreatinin 91 umol/l  (59-104) CKD-EPI CKD-EPI Krea 1.39 ml/s/1.73m2  (1-2.4) KM S-Kys.močová 417 umol/l  (202-417) Na S-Na 143 mmol/l  (136-145) K S-K 4.4 mmol/l  (3.5-5.1) Cl S-Cl 107 mmol/l  (98-107) Bi-celk. S-Bilirubin celk 13.1 umol/l  (2-21) ALT S-ALT 0.17 ukat/l  (0.17-0.83) AST S-AST 0.20 ukat/l  (0.17-0.85) GGT S-GMT 0.41 ukat/l  (0.17-1.19) ALP S-ALP 1.03 ukat/l  (0.67-2.15) LD S-LD 3.09 ukat/l  (2.25-3.75) Glukóza S-Glukosa 5.8 mmol/l  (3.9-5.6) CRP S-CRP 11.7 mg/l  (0-5) S: nově alopecie, ale znovu začaly vlasy dorůstat bez B symptomů O: ECOG 0, 90kg paricální alopecied bez hmatné lymfadenopatie ve všech lokalzkaícch břicho měkké, hepar nezv, slezina nezvětšena, dkk bez otoků Dg B-Chronická lyfatická leukémie     - opakovaně progredující on., delece 11q, high-risk, - st.p.provedení alogenní PBSCT, dárce HLA identická sestra, den 0 byl   16.10.2018, režim FLAMSA bez amsa/RIC Cy+TBI. - 15.11.2018  přetrvává smíšený chimerismus a flow MRD pozitivita ze   dřeně z 12/2018, proto snižována IS terapie, k 1/2019 pokles SC   (29%..11%...6%) - od 5.4.2019 ukončen CsA, - 15.5.20 PET/CT generalizovaná lymfadenopatie, bez zn Richterova   syndromu - terapie Imbruvica od 25.5.20 - 8.6.2020 efekt zlepšení trombocytopenie, obvkylý nárůst lymfocytozy   při dobrém efektu terapie, zmenší otoku LDK - 9.9.20 efekt parciální remsise (upravěno tromboytopenie, trvá   lymfocytoza, otoky dkk nejsou - kontrolní CT 5/2021 - regrese velikosti i počtu uzlin, menší slezina - přerušena imbruvica pro těžký průběh COVID 19, restart - 6.4.22 trvá paricální remise,  kontrolní CT restaging 29.6.22 - 5.5.22 parickál njíremsie, přerušit imbruvica před cholecystekotmií - CT 29/6/202: mírná progrese velikosti LU povšechně, největší 34x20   infrarenálně vlevo - pro asymptomatickou nemoc a fidg dg i reaktivní   lymfadenopatie při střevním infektu zatím pokračuje terapie ibrutinibem  předána žádost na kontlní CT žádám nyní St.p. těžkém průběhu COVID 19 12/21 Venookluzivní choroba jaterní dg. 16.10.2018, th defibrotide Septický šok s průkazem E.coli v HMK v období neutropenie po aloTx Syndrom anginy pectoris s malou myokardiální lézí 15.8.2018  - t.č. bez obtíží, není nikde sledován Hypogammaglobulinémie, substituce Kiovig naposledy 7.11.2018 Phlebotromboza LDK z útlaku masivní lymfadenopatií 9/2017 Herpes simplex horního rtu  v minulosti Herpes zoster 6/2015 ~do~Medikace:~df~ Imbruvica 140mg 3-0-0, zapít min. 200ml vody - Při užívání Imbruvicy je nutné vynechat konzumaci grapefruitů a třezalky. - Imbruvica může vést k poruše funkce krevních destiček, proto je   nutné tento lék před jakýmkoliv krvácivým výkonem vysadit 5-7 před   výkonem a nasadit zpět do medikace 5-7 dní po výkonu - Není vhodné současné podávání antikoagulační terapie warfarinem.   Pokud je nutno nasadit LMWH/heparin nebo DOAC, terapie Imbruvicou se musí   přechodně přerušit a její opětovné nasazení je nutné zkonzultovat s   naším centrem. - Imbruvica je metabolizována CYP3A4, před nasazením léků ovlivňujících   funkci tohoto enzymu je nutná konzultace s námi a event. úprava dávky   Imbruvicy - makrolidy, ciprofloxacin, azolová antimykotika, některá   antivirotika, diltiazem, verapamil, amiodaron, některá antiepileptika. - mezi nejčastější nežádoucí účinky imbruvicy patří krvácivé   k ...
# (26043815, 4712677, 1773067, datetime.date(2023, 1, 9), datetime.time(13, 11), 41742, '', 'C911 ', 'calquence                                                   ', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'Počátek vyšetření: 09.01.2023 12:53 Odběr:09.01.2023 10:18 Urea S-Urea 46.9 mmol/l (2.8-8.1) Kreat. S-Kreatinin 244 umol/l (45-84) CKD-EPI CKD-EPI Krea 0.25 ml/s/1.73m2 (1-2.4) KM S-Kys.močová 498 umol/l (143-339) Na S-Na 130 mmol/l (136-145) K S-K 6.0 mmol/l (3.5-5.1) Cl S-Cl 91 mmol/l (98-107) Bi-celk. S-Bilirubin celk 13.7 umol/l (2-21) ALT S-ALT 0.23 ukat/l (0.25-0.58) AST S-AST 0.36 ukat/l (0.17-0.6) GGT S-GMT 0.71 ukat/l (0.1-0.7) ALP S-ALP 2.38 ukat/l (0.58-1.74) Glukóza S-Glukosa 29.0 mmol/l (3.9-5.6) CRP S-CRP 5.1 mg/l (0-5) KOMENTAR KOMENTAR (-) Materiál S/P: :plazma Hlášeno tel. v :12.29 hod. kaliuum jistě s ovlivněním hyperleukocyzozou Odběr:09.01.2023 10:18 Ret% 4.91 % Reta 216.00 10^9/l IRF 0.334 WBC 321.000 10^9/l RBC 4.40 10^12/l HGB 129.0 g/l HCT 0.430 l/l MCV 97.1 fL PLT 157.0 10^9/l MCH 29.3 pg MCHC 302.0 g/l MPV 12.10 fl RDW 20.7 % NEU% 4.24 % LYM% 94.30 % MON% 0.91 % EOS% 0.00 % BAS% 0.55 % NEU 13.670 10^9/l LYM 303.000 10^9/l MONO 2.910 10^9/l EOS 0.000 10^9/l BASO 1.760 10^9/l NRBC 0.00 10^9/l NRBC/WBC 0.00 /100WBC HlášAnal : KOMENTAR Změna oproti předešlému Z provedených vyšetření: * 5/2022 SP:  RES: V buněčně bohatších až bohatých aspirátech infiltrace   KD patologickými lymfocyty (68,6%) v.s. při základním   lymfoproliferativním onemocnění (dle dok. CLL). - flow KD CLL 67% * CT restaging 16/6/2021   RES: V porovnání s minulým vyš. lymfadenopatie ve stac. počtu, některé   retroperitoneální LU lehce větší (největší LU v oblasti bifurkace aorty   32x8mm). Bez hepatosplenomegalie. Vlevo v S1/2 lehká progrese velikosti   plicní nodularity (6x3mm), ostatní nodularity bez podstatných změn.   slezina 110x55x127mm * EKG 14/11/2022: fibrilace síní s POK 52/min, QRS štíhlý, převoní   intervaly v normě, LAH * EKG 23/11/2022: interna Dr. Bartejsová, Česká, Brno - fisi 71/min Subj: ležící na lůžku, 1x zvracela, na dotaz co se děje odpovídá že nic, je unavenější, nemá chuť k jídlu, nic jí nebolí, teplotu nemá, dle příbuzné - cca týden je stav horší nevolnost navalování tři dn nyní už jen pila a trochu dibenu nejedla, teplotu nepozorovali Obj.: ECOG 3  váha 75kg výška 154cm ležící v lůžku, odpovídá spíše jednoslovně orientovaná, AS reg.  břicho klidné, měkké, bez rezistence, nebolestivé játra ani slezinu nehmatám, periferní uzliny: do 1 cm DKK otoky jen perimaleolárně DG.: Akutní renální selhání v terénu CHRI - k došetření, urémie, zvracení Hyperglykémie C911 CLL/malobuněčný lymfom typu CLL, diag. 7.04.2016 z nadklíčkové LU - klin.st. IV A non-bulky, patol. lymfadenopatie obou nadklíčků do   19 mm, L.axily a v RP max. 28mm, leukocytóza, lymfocytóza klonální - 12/2016 PET/CT na MOÚ, kde velikostní i početná progrese lymfadenopatie,   největší LU v tříslech 12x22mm, tedy nadále non-bulky - 6/2/2017 prognostické faktory: komplexní karyotyp, del 17p, 13q, PAT   pozit, TP 53 mutace potvrzena!  suchá aspirace ze SP v úvodu - 1. linie terapie: 5xRCP od 6/3-6/6/2017, klinický efekt SD - s ohledem na absenci zásadní symptomatologie a přítomnost dle 17p   a komplexního karyotypu při progresi nemoci v 2. linii campath, pro   zhoršení lymfedemu PHK kontrolní CT restaging - efekt progrese! - dle CT 12/10/2017 generalizovaná lymfadenopatie s maximem v dutině   břišní, kde max průměr až 150mm - pulz kortikoidů od 6/12/2017 - 2. linie terapie: alemtuzumab od 11/12/2017 do 3/4/2018, klin. efekt PD - další progrese nemoci, indikuji podání pulzního dexamethasonu -  14/9/2018 - CLL s mutací TP53, více jak 1 linie terapie, ECOG 1 - indikuji podání ibrutinibu, do 10/2019 byla výborná tolerance - ibrutinib přerušen pro herpes zoster - dle CT restagingu 14/11/2019 výrazná regrese lymfadenopatie, tedy   léčebná odpověď PR - od 17/2/2020 start ibrutinibu 140mg/den - k 25/5/2021 klinicky trvá parciální remise - ibru ...
# (26015332, 2480460, 3436, datetime.date(2023, 1, 9), datetime.time(15, 6), 41742, '', 'C911 ', 'venetoklax příjem IHOK                                      ', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'studie LOXO 20022, pacient číslo 2201-440 platí informované souhlasy studie LOXO 20022 ------------------------------------------------------ pacient naplnuje všechna inclusion kritéria, má  exclusion kritérium infekce dne 9.1.2023 psoeldní den, kdy je možná randomizace je 10.1.23, ale to ifnekce nebude doléčená informována monitorka studie medical history mikroskopická hematurie nejasné etiologie- infekce neprokázána, PSA v normě, CT IV urografie v normě,, uretrocystoskopie 5.1.2023 v normě, jen patrný útalk močového měcháře uzlinami zvenčí nově nasazena medikace lannatam 0,4mg p.o. denně od 5.1.23 hepatitidy negativní CMV negativní CT 16.12.22 Masivní lymfadenopatie ve všech krčních prostorech oboustranně - největší vpravo 68x38mm, uzliny jsou nakupeny paketovitě, stále ještě izolované, homogenní. Dále se uzlinové pakety propagují podél cévních svazků do nad/podklíčku i axill oboustranně - zde největší vpravo 52x32mm, vlevo 43x36mm. Štítná žláza homogenní - pouze vpravo v P laloku drobná hypodenzita 4mm. V mediastinu i v obou hilech také lymfadenopatie - v oblasti P hilu a subkarinně až splývající do homogenního infiltrátu vel.55x32 v P hilu a 52x29 subkarinně. Dále uzliny patrné paraaortálně a retrokrurálně. 3 nápadnější LU i při kardii. Plicní křídla jsou vzdušná, bez fluidothoraxu. Vpravo v S4 ložisko vel.8mm - větší než minule. Vlevo vazivový pruh v S5/8, v S9 a 10 jemná vazivová zesílení, místy zesílení inter/intralobulárního vaziva a bronchioloektázie. Játra KK v MDC 170mm,nativně jen lehce snížené denzity, postkontrastně jsou patrné tři hypodenzity stejné jako minule charakteru cyst. Žl.cesty štíhlé, žlučník se nezobrazuje. Porta, VMS i robustní VL se homogenně sytí. Slezina vel.207x93mm(VDxML) postkontrastně bez ložisek. Ledviny nativně bez denzit lithiázy, postkontrastně drobné cystičky, DS v normě. Pravá nadledvina štíhlá, vlevo v centrální porci drobný nodulus do 10mm. Slinivka bez zjevné expanze, v jejím okolí výrazně zvýšená denzita tuku, zmnoženy LU - vzájemně od sebe špatně odlišitelné. Za portou LU je LU vel.43x17mm, paraaortálně jsou nakupeny uzliny vel.do 25mm a neostré konturace. Paket uzlin a výrazný prosak tuku je i kolem radixu mesenteria. Pakety uzlin se táhnou i podél il.cévních svazků - vpravo max.97x57mm, vlevo 105x53mm, tyto uzliny v MP utlačují močový měchýř, který málo naplněn. prostata s centrálními hrubými kalcifikacemi. Prosáklá je i stěna rekta i tuk v jeho okolí, výrazný prosak tuku jak mesenteriálně, tak v RP. CD volné. Patologicky zvětšené LU prokazuji i v tříslech, vpravo max.41mm, vlevo 46mm. Skelet - hyperkyfóza hrudní i prohloubená bederní lordóza, skelet je lehce mléčné struktury. Degenerativní změny skeletu jsou patrné zejména v kaudální krční porci, na vrcholu Th kyfózy. Redukce MOP L3/4 s degen.změnami OT L3 dorsálně s jemným posunem dorsálně. RES. Výrazná progrese nálezu - dnes masivní lymfadenopatie ve všech vyšetřovaných oblastech, hepatomegalie, splenomegalie, prosak mesenteriálního a RP tuku. -------------------------------------------- cytogenetika FISH je delece genu TP53 4.3.2020 IGVH homologie 100% flow 3.11.22CD 19+skappa 81,9% CD 19+slambda 1,1% -------------------------------------------- histologie uzlina vpravo na krku odbr 28.11.22 Mikropopis: Lymfatická uzlina s architektonikou zcela setřenou plochami převážně malých kulatých lymfocytů, dále minoritně v proliferačních centrech (pseudofoliklech) jsou přítomny větší prolymfocyty i velké paraimunoblasty. Proliferační centra jsou místy neobvykle velká: přesahují 20x a úsekovitě jsou konfluentní, proliferační aktivita v nich dle Ki-67 je zvýšená (přesahuje 40%), počet mitóz v centru přesahuje 2,4. Neoplastické buňky jsou CD 20+, CD 19+, CD 79a+, PDL. PD-L1 (imunohistochemie): Protilátka: PDL1 Klon ...

# %%
##fetching all columns from database
cursor.execute(f"select * from {tableName}")
fetched_data = cursor.fetchmany(3)
for row in fetched_data:
    print(row)
# Out:
# (25775488, 3702287, 257353, datetime.date(2023, 1, 9), datetime.time(14, 47), 41742, '', 'C911 ', '', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'Odběr:09.01.2023 10:53 ------------------------------------------------------------  Ret% 1.67 %   Reta 59.50 10^9/l   IRF 0.258    RET-He 35.3 pg   WBC 27.700 10^9/l   RBC 3.56 10^12/l   HGB 122.0 g/l   HCT 0.360 l/l MCV 101.7 fL   PLT 129.0 10^9/l   MCH 34.3 pg   MCHC 337.0 g/l   MPV 9.30 fl   RDW 14.2 %   NEU% 1.60 %   LYM% 94.40 %   MON% 3.40 % EOS% 0.30 %   BAS% 0.30 %   NEU 0.480 10^9/l   LYM 26.150 10^9/l MONO 0.930 10^9/l   EOS 0.070 10^9/l   BASO 0.070 10^9/l   NRBC 0.04 Odběr:09.01.2023 10:52 Urea S-Urea 5.5 mmol/l  (2.8-8.1) Kreat. S-Kreatinin 91 umol/l  (59-104) CKD-EPI CKD-EPI Krea 1.39 ml/s/1.73m2  (1-2.4) KM S-Kys.močová 417 umol/l  (202-417) Na S-Na 143 mmol/l  (136-145) K S-K 4.4 mmol/l  (3.5-5.1) Cl S-Cl 107 mmol/l  (98-107) Bi-celk. S-Bilirubin celk 13.1 umol/l  (2-21) ALT S-ALT 0.17 ukat/l  (0.17-0.83) AST S-AST 0.20 ukat/l  (0.17-0.85) GGT S-GMT 0.41 ukat/l  (0.17-1.19) ALP S-ALP 1.03 ukat/l  (0.67-2.15) LD S-LD 3.09 ukat/l  (2.25-3.75) Glukóza S-Glukosa 5.8 mmol/l  (3.9-5.6) CRP S-CRP 11.7 mg/l  (0-5) S: nově alopecie, ale znovu začaly vlasy dorůstat bez B symptomů O: ECOG 0, 90kg paricální alopecied bez hmatné lymfadenopatie ve všech lokalzkaícch břicho měkké, hepar nezv, slezina nezvětšena, dkk bez otoků Dg B-Chronická lyfatická leukémie     - opakovaně progredující on., delece 11q, high-risk, - st.p.provedení alogenní PBSCT, dárce HLA identická sestra, den 0 byl   16.10.2018, režim FLAMSA bez amsa/RIC Cy+TBI. - 15.11.2018  přetrvává smíšený chimerismus a flow MRD pozitivita ze   dřeně z 12/2018, proto snižována IS terapie, k 1/2019 pokles SC   (29%..11%...6%) - od 5.4.2019 ukončen CsA, - 15.5.20 PET/CT generalizovaná lymfadenopatie, bez zn Richterova   syndromu - terapie Imbruvica od 25.5.20 - 8.6.2020 efekt zlepšení trombocytopenie, obvkylý nárůst lymfocytozy   při dobrém efektu terapie, zmenší otoku LDK - 9.9.20 efekt parciální remsise (upravěno tromboytopenie, trvá   lymfocytoza, otoky dkk nejsou - kontrolní CT 5/2021 - regrese velikosti i počtu uzlin, menší slezina - přerušena imbruvica pro těžký průběh COVID 19, restart - 6.4.22 trvá paricální remise,  kontrolní CT restaging 29.6.22 - 5.5.22 parickál njíremsie, přerušit imbruvica před cholecystekotmií - CT 29/6/202: mírná progrese velikosti LU povšechně, největší 34x20   infrarenálně vlevo - pro asymptomatickou nemoc a fidg dg i reaktivní   lymfadenopatie při střevním infektu zatím pokračuje terapie ibrutinibem  předána žádost na kontlní CT žádám nyní St.p. těžkém průběhu COVID 19 12/21 Venookluzivní choroba jaterní dg. 16.10.2018, th defibrotide Septický šok s průkazem E.coli v HMK v období neutropenie po aloTx Syndrom anginy pectoris s malou myokardiální lézí 15.8.2018  - t.č. bez obtíží, není nikde sledován Hypogammaglobulinémie, substituce Kiovig naposledy 7.11.2018 Phlebotromboza LDK z útlaku masivní lymfadenopatií 9/2017 Herpes simplex horního rtu  v minulosti Herpes zoster 6/2015 ~do~Medikace:~df~ Imbruvica 140mg 3-0-0, zapít min. 200ml vody - Při užívání Imbruvicy je nutné vynechat konzumaci grapefruitů a třezalky. - Imbruvica může vést k poruše funkce krevních destiček, proto je   nutné tento lék před jakýmkoliv krvácivým výkonem vysadit 5-7 před   výkonem a nasadit zpět do medikace 5-7 dní po výkonu - Není vhodné současné podávání antikoagulační terapie warfarinem.   Pokud je nutno nasadit LMWH/heparin nebo DOAC, terapie Imbruvicou se musí   přechodně přerušit a její opětovné nasazení je nutné zkonzultovat s   naším centrem. - Imbruvica je metabolizována CYP3A4, před nasazením léků ovlivňujících   funkci tohoto enzymu je nutná konzultace s námi a event. úprava dávky   Imbruvicy - makrolidy, ciprofloxacin, azolová antimykotika, některá   antivirotika, diltiazem, verapamil, amiodaron, některá antiepileptika. - mezi nejčastější nežádoucí účinky imbruvicy patří krvácivé   k ...
# (26043815, 4712677, 1773067, datetime.date(2023, 1, 9), datetime.time(13, 11), 41742, '', 'C911 ', 'calquence                                                   ', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'Počátek vyšetření: 09.01.2023 12:53 Odběr:09.01.2023 10:18 Urea S-Urea 46.9 mmol/l (2.8-8.1) Kreat. S-Kreatinin 244 umol/l (45-84) CKD-EPI CKD-EPI Krea 0.25 ml/s/1.73m2 (1-2.4) KM S-Kys.močová 498 umol/l (143-339) Na S-Na 130 mmol/l (136-145) K S-K 6.0 mmol/l (3.5-5.1) Cl S-Cl 91 mmol/l (98-107) Bi-celk. S-Bilirubin celk 13.7 umol/l (2-21) ALT S-ALT 0.23 ukat/l (0.25-0.58) AST S-AST 0.36 ukat/l (0.17-0.6) GGT S-GMT 0.71 ukat/l (0.1-0.7) ALP S-ALP 2.38 ukat/l (0.58-1.74) Glukóza S-Glukosa 29.0 mmol/l (3.9-5.6) CRP S-CRP 5.1 mg/l (0-5) KOMENTAR KOMENTAR (-) Materiál S/P: :plazma Hlášeno tel. v :12.29 hod. kaliuum jistě s ovlivněním hyperleukocyzozou Odběr:09.01.2023 10:18 Ret% 4.91 % Reta 216.00 10^9/l IRF 0.334 WBC 321.000 10^9/l RBC 4.40 10^12/l HGB 129.0 g/l HCT 0.430 l/l MCV 97.1 fL PLT 157.0 10^9/l MCH 29.3 pg MCHC 302.0 g/l MPV 12.10 fl RDW 20.7 % NEU% 4.24 % LYM% 94.30 % MON% 0.91 % EOS% 0.00 % BAS% 0.55 % NEU 13.670 10^9/l LYM 303.000 10^9/l MONO 2.910 10^9/l EOS 0.000 10^9/l BASO 1.760 10^9/l NRBC 0.00 10^9/l NRBC/WBC 0.00 /100WBC HlášAnal : KOMENTAR Změna oproti předešlému Z provedených vyšetření: * 5/2022 SP:  RES: V buněčně bohatších až bohatých aspirátech infiltrace   KD patologickými lymfocyty (68,6%) v.s. při základním   lymfoproliferativním onemocnění (dle dok. CLL). - flow KD CLL 67% * CT restaging 16/6/2021   RES: V porovnání s minulým vyš. lymfadenopatie ve stac. počtu, některé   retroperitoneální LU lehce větší (největší LU v oblasti bifurkace aorty   32x8mm). Bez hepatosplenomegalie. Vlevo v S1/2 lehká progrese velikosti   plicní nodularity (6x3mm), ostatní nodularity bez podstatných změn.   slezina 110x55x127mm * EKG 14/11/2022: fibrilace síní s POK 52/min, QRS štíhlý, převoní   intervaly v normě, LAH * EKG 23/11/2022: interna Dr. Bartejsová, Česká, Brno - fisi 71/min Subj: ležící na lůžku, 1x zvracela, na dotaz co se děje odpovídá že nic, je unavenější, nemá chuť k jídlu, nic jí nebolí, teplotu nemá, dle příbuzné - cca týden je stav horší nevolnost navalování tři dn nyní už jen pila a trochu dibenu nejedla, teplotu nepozorovali Obj.: ECOG 3  váha 75kg výška 154cm ležící v lůžku, odpovídá spíše jednoslovně orientovaná, AS reg.  břicho klidné, měkké, bez rezistence, nebolestivé játra ani slezinu nehmatám, periferní uzliny: do 1 cm DKK otoky jen perimaleolárně DG.: Akutní renální selhání v terénu CHRI - k došetření, urémie, zvracení Hyperglykémie C911 CLL/malobuněčný lymfom typu CLL, diag. 7.04.2016 z nadklíčkové LU - klin.st. IV A non-bulky, patol. lymfadenopatie obou nadklíčků do   19 mm, L.axily a v RP max. 28mm, leukocytóza, lymfocytóza klonální - 12/2016 PET/CT na MOÚ, kde velikostní i početná progrese lymfadenopatie,   největší LU v tříslech 12x22mm, tedy nadále non-bulky - 6/2/2017 prognostické faktory: komplexní karyotyp, del 17p, 13q, PAT   pozit, TP 53 mutace potvrzena!  suchá aspirace ze SP v úvodu - 1. linie terapie: 5xRCP od 6/3-6/6/2017, klinický efekt SD - s ohledem na absenci zásadní symptomatologie a přítomnost dle 17p   a komplexního karyotypu při progresi nemoci v 2. linii campath, pro   zhoršení lymfedemu PHK kontrolní CT restaging - efekt progrese! - dle CT 12/10/2017 generalizovaná lymfadenopatie s maximem v dutině   břišní, kde max průměr až 150mm - pulz kortikoidů od 6/12/2017 - 2. linie terapie: alemtuzumab od 11/12/2017 do 3/4/2018, klin. efekt PD - další progrese nemoci, indikuji podání pulzního dexamethasonu -  14/9/2018 - CLL s mutací TP53, více jak 1 linie terapie, ECOG 1 - indikuji podání ibrutinibu, do 10/2019 byla výborná tolerance - ibrutinib přerušen pro herpes zoster - dle CT restagingu 14/11/2019 výrazná regrese lymfadenopatie, tedy   léčebná odpověď PR - od 17/2/2020 start ibrutinibu 140mg/den - k 25/5/2021 klinicky trvá parciální remise - ibru ...
# (26015332, 2480460, 3436, datetime.date(2023, 1, 9), datetime.time(15, 6), 41742, '', 'C911 ', 'venetoklax příjem IHOK                                      ', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'studie LOXO 20022, pacient číslo 2201-440 platí informované souhlasy studie LOXO 20022 ------------------------------------------------------ pacient naplnuje všechna inclusion kritéria, má  exclusion kritérium infekce dne 9.1.2023 psoeldní den, kdy je možná randomizace je 10.1.23, ale to ifnekce nebude doléčená informována monitorka studie medical history mikroskopická hematurie nejasné etiologie- infekce neprokázána, PSA v normě, CT IV urografie v normě,, uretrocystoskopie 5.1.2023 v normě, jen patrný útalk močového měcháře uzlinami zvenčí nově nasazena medikace lannatam 0,4mg p.o. denně od 5.1.23 hepatitidy negativní CMV negativní CT 16.12.22 Masivní lymfadenopatie ve všech krčních prostorech oboustranně - největší vpravo 68x38mm, uzliny jsou nakupeny paketovitě, stále ještě izolované, homogenní. Dále se uzlinové pakety propagují podél cévních svazků do nad/podklíčku i axill oboustranně - zde největší vpravo 52x32mm, vlevo 43x36mm. Štítná žláza homogenní - pouze vpravo v P laloku drobná hypodenzita 4mm. V mediastinu i v obou hilech také lymfadenopatie - v oblasti P hilu a subkarinně až splývající do homogenního infiltrátu vel.55x32 v P hilu a 52x29 subkarinně. Dále uzliny patrné paraaortálně a retrokrurálně. 3 nápadnější LU i při kardii. Plicní křídla jsou vzdušná, bez fluidothoraxu. Vpravo v S4 ložisko vel.8mm - větší než minule. Vlevo vazivový pruh v S5/8, v S9 a 10 jemná vazivová zesílení, místy zesílení inter/intralobulárního vaziva a bronchioloektázie. Játra KK v MDC 170mm,nativně jen lehce snížené denzity, postkontrastně jsou patrné tři hypodenzity stejné jako minule charakteru cyst. Žl.cesty štíhlé, žlučník se nezobrazuje. Porta, VMS i robustní VL se homogenně sytí. Slezina vel.207x93mm(VDxML) postkontrastně bez ložisek. Ledviny nativně bez denzit lithiázy, postkontrastně drobné cystičky, DS v normě. Pravá nadledvina štíhlá, vlevo v centrální porci drobný nodulus do 10mm. Slinivka bez zjevné expanze, v jejím okolí výrazně zvýšená denzita tuku, zmnoženy LU - vzájemně od sebe špatně odlišitelné. Za portou LU je LU vel.43x17mm, paraaortálně jsou nakupeny uzliny vel.do 25mm a neostré konturace. Paket uzlin a výrazný prosak tuku je i kolem radixu mesenteria. Pakety uzlin se táhnou i podél il.cévních svazků - vpravo max.97x57mm, vlevo 105x53mm, tyto uzliny v MP utlačují močový měchýř, který málo naplněn. prostata s centrálními hrubými kalcifikacemi. Prosáklá je i stěna rekta i tuk v jeho okolí, výrazný prosak tuku jak mesenteriálně, tak v RP. CD volné. Patologicky zvětšené LU prokazuji i v tříslech, vpravo max.41mm, vlevo 46mm. Skelet - hyperkyfóza hrudní i prohloubená bederní lordóza, skelet je lehce mléčné struktury. Degenerativní změny skeletu jsou patrné zejména v kaudální krční porci, na vrcholu Th kyfózy. Redukce MOP L3/4 s degen.změnami OT L3 dorsálně s jemným posunem dorsálně. RES. Výrazná progrese nálezu - dnes masivní lymfadenopatie ve všech vyšetřovaných oblastech, hepatomegalie, splenomegalie, prosak mesenteriálního a RP tuku. -------------------------------------------- cytogenetika FISH je delece genu TP53 4.3.2020 IGVH homologie 100% flow 3.11.22CD 19+skappa 81,9% CD 19+slambda 1,1% -------------------------------------------- histologie uzlina vpravo na krku odbr 28.11.22 Mikropopis: Lymfatická uzlina s architektonikou zcela setřenou plochami převážně malých kulatých lymfocytů, dále minoritně v proliferačních centrech (pseudofoliklech) jsou přítomny větší prolymfocyty i velké paraimunoblasty. Proliferační centra jsou místy neobvykle velká: přesahují 20x a úsekovitě jsou konfluentní, proliferační aktivita v nich dle Ki-67 je zvýšená (přesahuje 40%), počet mitóz v centru přesahuje 2,4. Neoplastické buňky jsou CD 20+, CD 19+, CD 79a+, PDL. PD-L1 (imunohistochemie): Protilátka: PDL1 Klon ...

# %% [markdown]
# # Adding vector embeddings to the table

# %% [markdown]
# ## Create embeddings for the descriptions and add to the dataframe

# %%
from sentence_transformers import SentenceTransformer

# Load a pre-trained sentence transformer model. This model's output vectors are of size 384
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# Generate embeddings for all descriptions at once. Batch processing makes it faster
embeddings = model.encode(df['amb_zaz_text'].tolist(), normalize_embeddings=True)

# Add the embeddings to the DataFrame
df['amb_zaz_text_vector'] = embeddings.tolist()

# %%
df
# Out:
#       ic_amb_zad  ic_amb_karta   ic_pac     dat_zad   cas_zad  prac_od dg_kod  \
# 0       25775488       3702287   257353  2023-01-09  14:47:00    41742
# 1       26043815       4712677  1773067  2023-01-09  13:11:00    41742
# 2       26015332       2480460     3436  2023-01-09  15:06:00    41742
# 3       25567942       5809559  2135408  2023-01-09  15:04:00    41742
# 4       25833197       6059137    86335  2023-01-09  15:09:00    41742
# ...          ...           ...      ...         ...       ...      ...    ...
# 5567    27493925       6395394    19532  2023-12-28  12:42:00    41742
# 5568    27551604       5302898  2325924  2023-12-28  12:38:00    41742
# 5569    27551590       4465360   374750  2023-12-28  12:43:00    41742
# 5570    27565846       6849977  2100404  2023-12-29  09:09:00    41742
# 5571    27566474       6850110   665512  2023-12-29  10:44:00    41742
#
#      i_dg_kod                                            text_dg  \
# 0       C911
# 1       C911   calquence                                     ...
# 2       C911   venetoklax příjem IHOK                        ...
# 3       C911   kontrola                                      ...
# 4       C911   imbruvica                                     ...
# ...       ...                                                ...
# 5567    C911   LOXO, jen odběr KO                            ...
# 5568    C911   pouze odběr KO a odejít                       ...
# 5569    C911   pouze odběr KO a odejít                       ...
# 5570    C911
# 5571    C911
#
#                                               i_text_dg poz_text  \
# 0     Chronická lymfocytická leukemie z B-buněk     ...
# 1     Chronická lymfocytická leukemie z B-buněk     ...
# 2     Chronická lymfocytická leukemie z B-buněk     ...
# 3     Chronická lymfocytická leukemie z B-buněk     ...
# 4     Chronická lymfocytická leukemie z B-buněk     ...
# ...                                                 ...      ...
# 5567  Chronická lymfocytická leukemie z B-buněk     ...
# 5568  Chronická lymfocytická leukemie z B-buněk     ...
# 5569  Chronická lymfocytická leukemie z B-buněk     ...
# 5570  Chronická lymfocytická leukemie z B-buněk     ...
# 5571  Chronická lymfocytická leukemie z B-buněk     ...
#
#                                            amb_zaz_text  \
# 0     Odběr:09.01.2023 10:53 -----------------------...
# 1     Počátek vyšetření: 09.01.2023 12:53 Odběr:09.0...
# 2     studie LOXO 20022, pacient číslo 2201-440 plat...
# 3     Počátek vyšetření: 09.01.2023 14:39 Odběr:09.0...
# 4     Odběr:09.01.2023 10:54 -----------------------...
# ...                                                 ...
# 5567  Počátek vyšetření: 28.12.2023 08:41 C10 Studie...
# 5568  Počátek vyšetření: 28.12.2023 08:35 LOXO-BTK-2...
# 5569  C10D1 studie LOXO-BTK-20030, subj 2201-405 ---...
# 5570  Pac. s CLL/SLL léčená původně v r 2020 cestou ...
# 5571  ~uo~~do~TELEFONNÍ KONTAKT:~df~~uf~ pacient Pac...
#
#                                     amb_zaz_text_vector
# 0     [0.0362723171710968, 0.01610576920211315, 0.03...
# 1     [0.040446750819683075, 0.12473584711551666, 0....
# 2     [0.05710926279425621, 0.013156612403690815, -0...
# 3     [0.054597243666648865, 0.07014299929141998, 0....
# 4     [0.0338958241045475, 0.0340065136551857, 0.037...
# ...                                                 ...
# 5567  [0.06402770429849625, 0.05141748860478401, 0.0...
# 5568  [0.035097360610961914, -0.0036271417047828436,...
# 5569  [0.010818377137184143, 0.03816291689872742, 0....
# 5570  [-0.04853430017828941, 0.03359058126807213, -0...
# 5571  [0.00130856828764081, 0.03644166886806488, -0....
#
# [5572 rows x 13 columns]

# %% [markdown]
# ## Delete and create the table in IRIS again to add embeddings
# ### (Note: Alternately, the Alter Table command can be used to just add the new embeddings column : https://docs.intersystems.com/irislatest/csp/docbook/DocBook.UI.Page.cls?KEY=RSQL_altertable#RSQL_altertable_synopsis )

# %%
try:
    cursor.execute(f"DROP TABLE {tableName}")  
except:
    pass

## note the additional description_vector VECTOR(DOUBLE, 384) field to store embeddings
tableDefinition = """(ic_amb_zad INT, ic_amb_karta INT, ic_pac INT, 
                    dat_zad DATE, cas_zad DATETIME, prac_od INT, dg_kod MEDIUMTEXT, i_dg_kod MEDIUMTEXT, 
                    text_dg MEDIUMTEXT, i_text_dg MEDIUMTEXT, poz_text MEDIUMTEXT, amb_zaz_text LONGTEXT, amb_zaz_text_vector VECTOR(DOUBLE, 384))"""
cursor.execute(f"CREATE TABLE {tableName} {tableDefinition}")
# Out:
# 0

# %% [markdown]
# ## Add all the rows to the table in IRIS

# %% [markdown]
# ### Adding the entire dataframe as a single batch (faster)

# %%
sql = f"""Insert into {tableName} (ic_amb_zad, ic_amb_karta, ic_pac, 
                    dat_zad, cas_zad, prac_od, dg_kod, i_dg_kod, 
                    text_dg, i_text_dg, poz_text, amb_zaz_text, amb_zaz_text_vector) values (?,?,?,?,?,?,?,?,?,?,?,?, TO_VECTOR(?))"""

start_time = time.time()
# Prepare the list of tuples (parameters for each row)
data = [
    (
        row['ic_amb_zad'], row['ic_amb_karta'], row['ic_pac'], row['dat_zad'], row['cas_zad'], row['prac_od'], row['dg_kod'], row['i_dg_kod'], row['text_dg'], row['i_text_dg'], row['poz_text'], row['amb_zaz_text'],
        str(row['amb_zaz_text_vector']) 
    )
    for index, row in df.iterrows()
]

cursor.executemany(sql, data)
end_time = time.time()
print(f"time taken to add {len(df)} entries: {end_time-start_time} seconds")
# Out:
# time taken to add 5572 entries: 5.85303258895874 seconds

# %%
df.iloc[12]
# Out:
# ic_amb_zad                                                      26053765
# ic_amb_karta                                                     4402239
# ic_pac                                                           2106293
# dat_zad                                                       2023-01-02
# cas_zad                                                         08:46:00
# prac_od                                                            41742
# dg_kod
# i_dg_kod                                                           C911
# text_dg
# i_text_dg              Chronická lymfocytická leukemie z B-buněk     ...
# poz_text
# amb_zaz_text           Počátek vyšetření: 02.01.2023 08:45 pacient ze...
# amb_zaz_text_vector    [0.01057382021099329, 0.027324587106704712, -0...
# Name: 12, dtype: object

# %%
##looping through dataframe and adding all the data to IRIS table
sql = f"""Insert into {tableName} (ic_amb_zad, ic_amb_karta, ic_pac, 
                    dat_zad, cas_zad, prac_od, dg_kod, i_dg_kod, 
                    text_dg, i_text_dg, poz_text, amb_zaz_text, amb_zaz_text_vector) values (?,?,?,?,?,?,?,?,?,?,?,?, TO_VECTOR(?))"""
start_time = time.time()
for index,row in df.iterrows():
    data = (row['ic_amb_zad'], row['ic_amb_karta'], row['ic_pac'], row['dat_zad'], row['cas_zad'], 
            row['prac_od'], row['dg_kod'], row['i_dg_kod'], row['text_dg'], row['i_text_dg'], row['poz_text'], row['amb_zaz_text'], str(row['amb_zaz_text_vector']) )
    #cursor.execute(sql, data)
    try:
        cursor.execute(sql, data)
    except RuntimeError as e:
        print(f"Error inserting row {index}: {e}")
end_time = time.time()
print(f"time taken to add {len(df)} entries: {end_time-start_time} seconds")
# Out:
# Error inserting row 0: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3F989CC6329BAEEFC70B9E00D6C1AD50@$vector') failed validation>]
# Error inserting row 1: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '265A701220AD55264EBBAC5808FCCE22@$vector') failed validation>]
# Error inserting row 2: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '03D26AC8EE9686AC1F24128F7C576255@$vector') failed validation>]
# Error inserting row 3: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'FB5575FE8C3731D1CA025B1504FD3B3D@$vector') failed validation>]
# Error inserting row 4: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'FD211E90BF82233CC007358E12CFA862@$vector') failed validation>]
# Error inserting row 5: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '72AE8E1E4A7616C01C42E360681FCDA5@$vector') failed validation>]
# Error inserting row 6: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EE2D80219A99DF4FD3B4E7E5BC4460CC@$vector') failed validation>]
# Error inserting row 7: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C025C841D7399AD3A4D8A6A212461BE3@$vector') failed validation>]
# Error inserting row 8: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '4D6411EE62C3294CC17A6574FF3768E4@$vector') failed validation>]
# Error inserting row 9: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '05FF558D422C47A6AA415AAF568DA8BF@$vector') failed validation>]
# Error inserting row 10: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'CFAB82BEE7B29E1F1ECE368988DEB203@$vector') failed validation>]
# Error inserting row 11: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'D6B0D45287D3A01FAAAF12678E952C78@$vector') failed validation>]
# Error inserting row 12: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '1259A887BB9013B5EE23C92A857C9070@$vector') failed validation>]
# Error inserting row 13: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '61805091519847B6997A9D4B305873A2@$vector') failed validation>]
# Error inserting row 14: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '20AD4A8F24087B408E134C64F819A741@$vector') failed validation>]
# Error inserting row 15: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'B5EBAB97D1E17159053F29B6A4CA06B5@$vector') failed validation>]
# Error inserting row 16: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '7F9EFF82CCE8EBE754FDCA607B47C1B4@$vector') failed validation>]
# Error inserting row 17: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F65F501CF9AC89A64B58BD9C3E73A1F6@$vector') failed validation>]
# Error inserting row 18: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '85E813DCDFBA35FDAE3C62E4B6714F6F@$vector') failed validation>]
# Error inserting row 19: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '93300BBBBA75AEBC73D4C6ECF4076382@$vector') failed validation>]
# Error inserting row 20: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EA71F31A061F72D18966B3849D4F1986@$vector') failed validation>]
# Error inserting row 21: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '2D9919A90733B3C68201CD8C57B9F31F@$vector') failed validation>]
# Error inserting row 22: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EAE1E8CFE4C33B772ACF4DF11073DD72@$vector') failed validation>]
# Error inserting row 23: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'DD7C9E574534D518639ECC8C280FDA86@$vector') failed validation>]
# Error inserting row 24: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '4C801A921C8F1DC997C61C8DE8EAD0E5@$vector') failed validation>]
# Error inserting row 25: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'D7383A39870C7B8BD919C1F0D4D67107@$vector') failed validation>]
# Error inserting row 26: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '772F50114A8CFA5B107D30133155F041@$vector') failed validation>]
# Error inserting row 27: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'DE7D2892979C4DAB5DCE5A562D1B990A@$vector') failed validation>]
# Error inserting row 28: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A4170E062F2834BDD9B004A9FB85A83A@$vector') failed validation>]
# Error inserting row 29: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '21F629532319DC58AE9D5B36094A8B02@$vector') failed validation>]
# Error inserting row 30: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '55384D676ED878AE21AE64648DCFFD91@$vector') failed validation>]
# Error inserting row 31: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '98EE15502F57D4CECF7BB89F51ED91BC@$vector') failed validation>]
# Error inserting row 32: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F885669286E0C8AB28CB033CFB819426@$vector') failed validation>]
# Error inserting row 33: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '78130B3EFEBDE559846E0882CA9D6059@$vector') failed validation>]
# Error inserting row 34: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C7911634422B43B83DE1312A237E8419@$vector') failed validation>]
# Error inserting row 35: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '62E4E369DB75A1AF8C8A6F797F5B5684@$vector') failed validation>]
# Error inserting row 36: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'D49D0170DBED88A8E1A5957C2DD0ECAB@$vector') failed validation>]
# Error inserting row 37: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'ADE319B6C80A564554DA8B606B3B52A1@$vector') failed validation>]
# Error inserting row 38: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'D15D286436814EEE5912582BA64F6541@$vector') failed validation>]
# Error inserting row 39: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '1BC27607E9D1CE500A8E94AD37A35B05@$vector') failed validation>]
# Error inserting row 40: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '8F1D676E31746D28CFF22F7F559C916D@$vector') failed validation>]
# Error inserting row 41: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '019FFBA883B85F7BA78267D64413A114@$vector') failed validation>]
# Error inserting row 42: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '5E824BFECF5DCEFA9B1F404EE3CF52BD@$vector') failed validation>]
# Error inserting row 43: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '130F5A95659D45687A4D097198CEDDF6@$vector') failed validation>]
# Error inserting row 44: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '397E461339CFF5F9AEA84BAA7775579F@$vector') failed validation>]
# Error inserting row 45: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '711FBBAA8BB899E9F81199E1A144BD50@$vector') failed validation>]
# Error inserting row 46: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A414760FF86918505FE62B52B4674DF8@$vector') failed validation>]
# Error inserting row 47: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'B02432227D65866F1DC71E5F38B9CA45@$vector') failed validation>]
# Error inserting row 48: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F4CFD1AEB9271826791E8F3120B75765@$vector') failed validation>]
# Error inserting row 49: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '18CB23FA1284BF31C9EA0F79E0A49600@$vector') failed validation>]
# Error inserting row 50: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '9F8463519613A141ED07FF43D7F3198B@$vector') failed validation>]
# Error inserting row 51: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'CB8A3CB48CE97020437EE1C48E7E0821@$vector') failed validation>]
# Error inserting row 52: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A82AA438247954B2AAD512880390105F@$vector') failed validation>]
# Error inserting row 53: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '4B2C7CEA74D0B6CD1D5957E64F645D7C@$vector') failed validation>]
# Error inserting row 54: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F0DD9B1AA8C689E3D32635D24BF65CE8@$vector') failed validation>]
# Error inserting row 55: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3D86B1CB01238EAD64562DA49D258E0E@$vector') failed validation>]
# Error inserting row 56: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3532096303C980CB5A14B95B14A1E2B5@$vector') failed validation>]
# Error inserting row 57: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A11ECE4DE524B177EB671AF30891954B@$vector') failed validation>]
# Error inserting row 58: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'CC5D8F6965F91DD3929C226758E2B21A@$vector') failed validation>]
# Error inserting row 59: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '6A52334649838872EEEFFAC51EC0524B@$vector') failed validation>]
# Error inserting row 60: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '144B3E4B4F1122AB5BD85FE574FD027C@$vector') failed validation>]
# Error inserting row 61: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '30BC441157B9A2E2E4EBACDA267C0796@$vector') failed validation>]
# Error inserting row 62: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C93ACE2316BC07EB17FF637F943CECA5@$vector') failed validation>]
# Error inserting row 63: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '6FE140D2E9E4EB82A0118445E98A1D91@$vector') failed validation>]
# Error inserting row 64: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0EAE811BB2154D5EB7BDE54F9D4044C2@$vector') failed validation>]
# Error inserting row 65: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'FC22114C6B721AECF7E6897A701B4134@$vector') failed validation>]
# Error inserting row 66: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C2375EAEA5427882FE1022BEDE514F7C@$vector') failed validation>]
# Error inserting row 67: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '385864D7F4BC6009B4D32F14833DF534@$vector') failed validation>]
# Error inserting row 68: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '1869DD325A24A2D40D38C586914BF1F4@$vector') failed validation>]
# Error inserting row 69: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F3D7DE700A2FC70DEB15E74F3067CD4A@$vector') failed validation>]
# Error inserting row 70: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '2A64524D1542378B20D0D1B44FF8520C@$vector') failed validation>]
# Error inserting row 71: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '9D02B55FCBA9D80E48978B6968304BEF@$vector') failed validation>]
# Error inserting row 72: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EDE9ED62042AEB4A8EC2459208A6F30C@$vector') failed validation>]
# Error inserting row 73: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '5707F2D16B2897BDD7A3D073A044B904@$vector') failed validation>]
# Error inserting row 74: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '64D11E316A72EFC98BFD7536C8CAE83F@$vector') failed validation>]
# Error inserting row 75: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A70CCF2AF018CF6E121247C5DA9B397A@$vector') failed validation>]
# Error inserting row 76: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EBCC178B4665520EC1D07EED932123E0@$vector') failed validation>]
# Error inserting row 77: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A11B12832BCAA1A505D9F5FA7FED0ACB@$vector') failed validation>]
# Error inserting row 78: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0CB9BA5F187B5548C7379E1B3C420A1E@$vector') failed validation>]
# Error inserting row 79: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'E067ADD3ADAA3410574AF0AC9BC4F610@$vector') failed validation>]
# Error inserting row 80: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'FDC87D2BA30123CDAF31F25433BB35F9@$vector') failed validation>]
# Error inserting row 81: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'ECF11ED89F0E056C66DCFAD6B889D9EE@$vector') failed validation>]
# Error inserting row 82: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C48B52BF61C922FC825ECE9837281233@$vector') failed validation>]
# Error inserting row 83: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '7E90E83BC38E0D80E69E6015342DC41B@$vector') failed validation>]
# Error inserting row 84: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '04B2E3BE972300854CD6E0C157DD5392@$vector') failed validation>]
# Error inserting row 85: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'E76340F348183F96182D703AE585B9CB@$vector') failed validation>]
# Error inserting row 86: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '29B916274DF1417273FC862294B4DC44@$vector') failed validation>]
# Error inserting row 87: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'D3AB1EE93B549FB044944A034FCF91EB@$vector') failed validation>]
# Error inserting row 88: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3E768A23AF2C70D4E279491AB6A0BBC4@$vector') failed validation>]
# Error inserting row 89: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '928DCB0931FE623BD5BD1C03DC9D1FFF@$vector') failed validation>]
# Error inserting row 90: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0404824E0D46FC5E07BE010FB8768C39@$vector') failed validation>]
# Error inserting row 91: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A278BEFC269EDB90E8690D425577D4E6@$vector') failed validation>]
# Error inserting row 92: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0ACCB629F2E1A22450C3CF3B48E4F8E6@$vector') failed validation>]
# Error inserting row 93: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '292589B1943CC927A3B550758F483263@$vector') failed validation>]
# Error inserting row 94: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'BD9F8B3A8ED6E1696340B8F320A65699@$vector') failed validation>]
# Error inserting row 95: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '7643428F1E0641AA19BECB1EB639B479@$vector') failed validation>]
# Error inserting row 96: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '2C32845262606EC48B53FEE0821849F5@$vector') failed validation>]
# Error inserting row 97: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '45C7B13B32E6F38BCC543A06F8D80FB0@$vector') failed validation>]
# Error inserting row 98: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C0DD5799BB64571112BE9542493B8FFB@$vector') failed validation>]
# Error inserting row 99: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '87A612B59F15881C47A24859C15CF287@$vector') failed validation>]
# Error inserting row 100: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '9F73319C8515842AD8DFD1D50E824555@$vector') failed validation>]
# Error inserting row 101: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '7714894B7E6DAC03C9C4BCC4326E93C7@$vector') failed validation>]
# Error inserting row 102: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0CEAE558D2E469118AE98F4C977F881A@$vector') failed validation>]
# Error inserting row 103: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C99FA3E51013BEFE1F24C449AEE3ED3D@$vector') failed validation>]
# Error inserting row 104: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '922DF4C0C4A2AE2B5EBE2F8CC16C128A@$vector') failed validation>]
# Error inserting row 105: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '2DEC954F36313CB18049C25D767D5640@$vector') failed validation>]
# Error inserting row 106: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3343FA9A9B398310ABCDEB60EEC84314@$vector') failed validation>]
# Error inserting row 107: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '50A5AC5716453D8A4C577C34F522D3E7@$vector') failed validation>]
# Error inserting row 108: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0E1F2EBE1ABE80BBCDDDFC7B57840DCF@$vector') failed validation>]
# Error inserting row 109: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '9ACF938BBF1E3D8DEB730E036539E066@$vector') failed validation>]
# Error inserting row 110: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'B6B47A31B9859DB19834CE18BA28E011@$vector') failed validation>]
# Error inserting row 111: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '94470B44AB16D262C6705007FAB62221@$vector') failed validation>]
# Error inserting row 112: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '917AFDE621D3C6AC4CC531CAB706BB05@$vector') failed validation>]
# Error inserting row 113: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0551C0B303C85D605FFC62B483BD31E7@$vector') failed validation>]
# Error inserting row 114: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'FC72D6C36583B9FA27A56931C5754D4E@$vector') failed validation>]
# Error inserting row 115: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '6FDCAFA03A1ED84FDD78F192A89E567D@$vector') failed validation>]
# Error inserting row 116: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C5F1E0B32B5048D7DD1F49B3C8944B4C@$vector') failed validation>]
# Error inserting row 117: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '01606DA94D119E90A0017D2C63E7DCC9@$vector') failed validation>]
# Error inserting row 118: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '875A3F636D0CE158BB13913A59522B35@$vector') failed validation>]
# Error inserting row 119: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A0555EDCEEE5E41DF00167C7F2E82D06@$vector') failed validation>]
# Error inserting row 120: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C310D69741E19E31A58C6628AF62FCAA@$vector') failed validation>]
# Error inserting row 121: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0591A68360193B922D36A66151F4FA0C@$vector') failed validation>]
# Error inserting row 122: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C7D3EB47A1825D2E74359F8C6545ADFF@$vector') failed validation>]
# Error inserting row 123: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '2855E899F2213BAFFF964C2D3B85C579@$vector') failed validation>]
# Error inserting row 124: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '81362D5B8F4898BAF5E590F80AF28F50@$vector') failed validation>]
# Error inserting row 125: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '096CF9BAF544FB0B161C5290C5A02ED3@$vector') failed validation>]
# Error inserting row 126: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F923353229B411C8C785DA79EC85269A@$vector') failed validation>]
# Error inserting row 127: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3D85F926DCB56011960F4C761760AC5B@$vector') failed validation>]
# Error inserting row 128: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '45277387076A7915070684729204E3CC@$vector') failed validation>]
# Error inserting row 129: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '201BC3E97E2FF4C618E982CE26A08B84@$vector') failed validation>]
# Error inserting row 130: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F8E3BCB1BA8B0843DECD133805BB185B@$vector') failed validation>]
# Error inserting row 131: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '236535445E3470418D6F37F71EF3C89B@$vector') failed validation>]
# Error inserting row 132: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A6F248E481DDF5D128463EED31F28498@$vector') failed validation>]
# Error inserting row 133: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '55A35E3D88F43B1029A3CDB579E87AEF@$vector') failed validation>]
# Error inserting row 134: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A041CC9AC69EC228DF407A6D4C43C60A@$vector') failed validation>]
# Error inserting row 135: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3F3209ACB983D73ABF0ED380EF7AACE0@$vector') failed validation>]
# Error inserting row 136: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EF8D07E55C7A5FC6CC1D0E36400EE180@$vector') failed validation>]
# Error inserting row 137: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'FF212548AF7C37F8F3E437B31C00E52B@$vector') failed validation>]
# Error inserting row 138: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '5346D3AD50665AA88ED8ACFD7BCA2A18@$vector') failed validation>]
# Error inserting row 139: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '9109205B750C81441B9F2ACD899056EB@$vector') failed validation>]
# Error inserting row 140: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '51EC39CC086E647525C20CE1AADF4BED@$vector') failed validation>]
# Error inserting row 141: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '094DAFFB19222DA361739A9C52E21D94@$vector') failed validation>]
# Error inserting row 142: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '1D5F06E2980B4A6D8BD35B481DB5DED9@$vector') failed validation>]
# Error inserting row 143: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '83103E69D69A663CC3E640B047E97C49@$vector') failed validation>]
# Error inserting row 144: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'AE05E71183D7EABB9F6C4C11B2863C0D@$vector') failed validation>]
# Error inserting row 145: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'DDF4FBCC93AEBBB7663A8F49B355D127@$vector') failed validation>]
# Error inserting row 146: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '846109D234EDA7FD075FF34D07AB76E3@$vector') failed validation>]
# Error inserting row 147: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '4042660CFF7EA62EA99C2C39C883735A@$vector') failed validation>]
# Error inserting row 148: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '8809BC185AABC9D90F9BAC5130FBB879@$vector') failed validation>]
# Error inserting row 149: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A816BECFA1DC1FBBED628C80F8DBB31D@$vector') failed validation>]
# Error inserting row 150: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '57578ED2986CD2CAB15BBA18D5A97C24@$vector') failed validation>]
# Error inserting row 151: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'D8E4A5C2E82D2B86ABCE6376A839B8F5@$vector') failed validation>]
# Error inserting row 152: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'BCC88EF149BA4D92E95E83593D5E23AD@$vector') failed validation>]
# Error inserting row 153: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '9AB02B9177CE6ACCA322A5EED6D02171@$vector') failed validation>]
# Error inserting row 154: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A11ECE4DE524B177EB671AF30891954B@$vector') failed validation>]
# Error inserting row 155: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '921304F61673F09866DF7DE3A6C740A4@$vector') failed validation>]
# Error inserting row 156: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0F25375ED354C39CA57E35F264B222ED@$vector') failed validation>]
# Error inserting row 157: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EF3ABD6D57AB0B139AD32708D509E500@$vector') failed validation>]
# Error inserting row 158: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '8EC80684AAEDFDC6361A30882ABA77A1@$vector') failed validation>]
# Error inserting row 159: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '5E70F84E3D077BE736140EBABF9F34CB@$vector') failed validation>]
# Error inserting row 160: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '389DEBE6E5AE7AF5382118942B5E86A1@$vector') failed validation>]
# Error inserting row 161: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# ...
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C807EFF4F55B3FFFE22833F27C049167@$vector') failed validation>]
# Error inserting row 5519: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'B392F607C2F36DA3377ACAD579A0BA76@$vector') failed validation>]
# Error inserting row 5520: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'BB47C3CEA2DDAF20335248D3CC382CA5@$vector') failed validation>]
# Error inserting row 5521: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '861CB6EC740ECB6398F6778480BF41A6@$vector') failed validation>]
# Error inserting row 5522: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C139F77CEB7F31BEF958F84BED1BFF5A@$vector') failed validation>]
# Error inserting row 5523: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '7657B3AEEF80561481313D9F324A431C@$vector') failed validation>]
# Error inserting row 5524: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '5746DCB0554DB80833246CAEE6C286F3@$vector') failed validation>]
# Error inserting row 5525: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3604F398D63CE6A035C68DA7AE88C75F@$vector') failed validation>]
# Error inserting row 5526: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '403D9BFC6B31D57D9406C9B94AD15CFB@$vector') failed validation>]
# Error inserting row 5527: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '6AC93B387362257F8694D31DB39C1CB2@$vector') failed validation>]
# Error inserting row 5528: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '11FE87209D7BDAD0F3A08912C1DC5A8E@$vector') failed validation>]
# Error inserting row 5529: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '82E5DBE7E73E584C30B26C4DCE278E2B@$vector') failed validation>]
# Error inserting row 5530: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '6DFAFDA45946ADE64F756F4AC9E2D6B6@$vector') failed validation>]
# Error inserting row 5531: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'D8B121A5F73D0EB3BC209F26A0722CC4@$vector') failed validation>]
# Error inserting row 5532: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '5D1B53A6621F4624C62709E0026305AC@$vector') failed validation>]
# Error inserting row 5533: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '14A9954099E6DF85B312B8776884CE8A@$vector') failed validation>]
# Error inserting row 5534: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '03935DC6D51DEB3D01A91E9760982A66@$vector') failed validation>]
# Error inserting row 5535: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '124214A34B672E27FBE9578C31834149@$vector') failed validation>]
# Error inserting row 5536: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '5856697042EB62CCDC1B79F4FA527B4F@$vector') failed validation>]
# Error inserting row 5537: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '27C310A264289A9641AB1EECCE1862D8@$vector') failed validation>]
# Error inserting row 5538: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EF67E5CBAB61C7F3012C5EB413C6CC30@$vector') failed validation>]
# Error inserting row 5539: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F8CEB9B6568F6A56A2D1B488ECE00442@$vector') failed validation>]
# Error inserting row 5540: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'B22A64A1EAA5E6247E5362809F0E802F@$vector') failed validation>]
# Error inserting row 5541: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '68AE24D0F13C10F6A8C50D18356BAEEC@$vector') failed validation>]
# Error inserting row 5542: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'BEC5E2F942DF9C39734D7F9AD9C562C5@$vector') failed validation>]
# Error inserting row 5543: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '57989520952284EFE60043F8154DF36E@$vector') failed validation>]
# Error inserting row 5544: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '4D6879A429536C6E4BEB5B253C6C0E74@$vector') failed validation>]
# Error inserting row 5545: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '23107BD8D715ABD6D6AE04A827882564@$vector') failed validation>]
# Error inserting row 5546: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '024072CC6238AE363DA1B523F1242C90@$vector') failed validation>]
# Error inserting row 5547: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '0775C7ECCA064F07CAC753B6E685E802@$vector') failed validation>]
# Error inserting row 5548: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'BCC84CFAE6B767F2E5A22B4663D1366B@$vector') failed validation>]
# Error inserting row 5549: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '7EBD4DE2BED694C040FD945D06C3B5EA@$vector') failed validation>]
# Error inserting row 5550: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'DC96E4A2AC805D6124E8709DF38F49D0@$vector') failed validation>]
# Error inserting row 5551: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'E13324F1DAD51A736F98F714FC547FFD@$vector') failed validation>]
# Error inserting row 5552: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '3FF168BE606D989A0888F40CBD667391@$vector') failed validation>]
# Error inserting row 5553: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '71E2728DA22E2AD4EF1F351AA11A051F@$vector') failed validation>]
# Error inserting row 5554: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '6A79EE354D6F9E4DA24F7218DBBD9A29@$vector') failed validation>]
# Error inserting row 5555: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C2D91C9E9AEAAB3F5AA547D19325CE52@$vector') failed validation>]
# Error inserting row 5556: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'EBF7451B21B2F46278ACEE731FEED0FC@$vector') failed validation>]
# Error inserting row 5557: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '6EE412F714E7C7C9220AF1C7FBFEBD2B@$vector') failed validation>]
# Error inserting row 5558: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A9F2757120C28FBCC332F8BC31B2CE4C@$vector') failed validation>]
# Error inserting row 5559: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'C0B1273D79CA2CF7D2C389F04008F8D0@$vector') failed validation>]
# Error inserting row 5560: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '44D61AE5CAF4186BE952178350D118AA@$vector') failed validation>]
# Error inserting row 5561: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '8E460BFC4768A98560F245443687F37C@$vector') failed validation>]
# Error inserting row 5562: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '14582236B3744D5305B3FC0FCF9E85D2@$vector') failed validation>]
# Error inserting row 5563: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '56C9F0835586BFCAC98456188EBD09F5@$vector') failed validation>]
# Error inserting row 5564: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'BB2BB6AF3333199C271345DEF6757CBD@$vector') failed validation>]
# Error inserting row 5565: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'D8D7BF1450CCA7A912D796CB2D8FE306@$vector') failed validation>]
# Error inserting row 5566: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F706BF0F098A8AE951D41F034FCAF5ED@$vector') failed validation>]
# Error inserting row 5567: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '9AA86106864377B9F9DED6003E21340B@$vector') failed validation>]
# Error inserting row 5568: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'F8B1FD62996CB2A01CA87EA370BFDBCB@$vector') failed validation>]
# Error inserting row 5569: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value 'A8B226EBC75F6806A2D163D55F1F4197@$vector') failed validation>]
# Error inserting row 5570: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '37B7A0A377A987BF6CB8538A411D71FF@$vector') failed validation>]
# Error inserting row 5571: [SQLCODE: <-104>:<Field validation failed in INSERT, or value failed to convert in DisplayToLogical or OdbcToLogical>]
# [Location: <ServerLoop>]
# [%msg: <Field 'SchemaName.TableName.amb_zaz_text_vector' (value '31CA241EBFF6450FE378F781E142D626@$vector') failed validation>]
# time taken to add 5572 entries: 6.684140920639038 seconds

# %% [markdown]
# # Using IRIS Vector Search

# %% [markdown]
# ## Let's look for a scotch that costs less than $100, and has an earthy and creamy taste.

# %%
# This is our search phrase
searchPhrase = "Začátek vyšetření"

# Convert search phrase into a vector
searchVector = model.encode(searchPhrase, normalize_embeddings=True).tolist()

# %%
sql = f"""
    SELECT TOP ? VECTOR_DOT_PRODUCT(amb_zaz_text_vector, TO_VECTOR(?)) AS POMOC, *
    FROM {tableName}
    WHERE ic_pac=2127268
    ORDER BY VECTOR_DOT_PRODUCT(amb_zaz_text_vector, TO_VECTOR(?)) DESC 
"""

numberOfResults = 3

# Execute the query with the number of results and search vector as parameters
cursor.execute(sql, [numberOfResults, str(searchVector), str(searchVector)])

# Fetch all results
results = cursor.fetchall()
for row in results:
    print(row[:-1])
# Out:
# (0.20761446067750722, 26258369, 4495603, 2127268, datetime.date(2023, 4, 13), datetime.datetime(1900, 1, 1, 9, 33), 41742, '', 'C911 ', 'venetoclax                                                  ', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'Počátek vyšetření: 13.04.2023 08:39 Odběr:13.04.2023 07:11 WBC 6.200 10^9/l RBC 4.91 10^12/l HGB 133.0 g/l HCT 0.410 l/l MCV 82.7 fL PLT 153.0 10^9/l MCH 27.1 pg MCHC 328.0 g/l MPV 8.60 fl RDW 13.4 % NEU% 63.40 % LYM% 24.20 % MON% 12.10 % EOS% 0.00 % BAS% 0.30 % NEU 3.930 10^9/l LYM 1.500 10^9/l MONO 0.750 10^9/l EOS 0.000 10^9/l BASO 0.020 10^9/l NRBC 0.00 10^9/l NRBC/WBC 0.00 /100WBC Odběr:13.04.2023 07:11 Urea S-Urea 5.2 mmol/l (2.8-8.1) Kreat. S-Kreatinin 71 umol/l (62-106) CKD-EPI CKD-EPI Krea 1.65 ml/s/1.73m2 (1-2.4) KM S-Kys.močová 147 umol/l (202-417) Na S-Na 138 mmol/l (136-145) K S-K 5.1 mmol/l (3.5-5.1) Cl S-Cl 102 mmol/l (98-107) Ca S-Ca 2.33 mmol/l (2.15-2.55) P S-P 0.76 mmol/l (0.81-1.45) Mg S-Mg 0.89 mmol/l (0.71-0.94) Bi-celk. S-Bilirubin celk 6.6 umol/l (2-21) ALT S-ALT 0.55 ukat/l (0.17-0.83) AST S-AST 0.42 ukat/l (0.17-0.85) GGT S-GMT 0.61 ukat/l (0.17-1.19) ALP S-ALP 2.27 ukat/l (0.67-2.15) LD S-LD 3.87 ukat/l (2.25-3.75) Glukóza S-Glukosa 11.3 mmol/l (3.9-5.6) CRP S-CRP 16.3 mg/l (0-5) Materiál S/P:    :plazma S: nemá žádné potíže, cítí se dobře, bez teplot, nechlazen není, venclyxto snáší dobře. Mívá pálení žáhyk večeru. Bez B symptomů. O:ECOG 1 du čistá, jazyk vlhký oběhově komp, orientován, eupnoe, uzliny na krku nehmatné, podpaží nehmatné, třísla nehmatné, břicho vzhledem k habitu hůře prohmatné, nebolestivé, játra nehmatám, slezinu nehmatám dkk chron změny bez otoků ~do~C911 Chronická B-lymfocytární leukemie, dg. z flow 15.4.2016~df~ - RAI IVA, Binet C ( lymfocyotza, trombocytopenie, hraniční anemie, bez   hmatné periferní lyfadenopatie) - nová dg, odběr prognostických faktorů na JIP IHOK 15.4.16, není AIHA - nález v likvoru také pozitivní, ale příměs krve, neuropatie a třes   při DM, t.č. zcela bez neurologické symptomatologie, etiolgoie jen   infekce, neprováděno MR mozku, infiltrace není pravdpěodobná - 1 linie léčby 2x FCR 19.4. a 18.5.2016 efekt SD - 4/2016 nově mutace TP 53 a delece 17p, IgVH nemutovaný, CD 38  negativní   cytogenetika delece 17p  77% - komplikováno recidivující bronchopneumonií - 2. linie  13.7.2016  1. RCD - 3. linie 10.8.2016 alemtuzumab, efekt 5.9.16 jako PR ( vstupně 4/2016   trombocytopenie, anemie, splenomegalie, lymfadenopatie v oblati mesenteria   a retroperitoenea dle sonografie, teploty, váhový úbytek) - 13.10.2016 krevní obraz zcela v normně, dle sonografie břicha   splenomegalie 19cm, četné uzliny paraaortálně 25mm   efekt hodnotím jako PR 13.10.2016 po aplikaci 4 týdnů - nyní observace, ukončeno pro listeriozovou sepsi 7.9.2016 - progrese 23.3.2017, RAi IVA, trombocytopenie   sonograficky lehká splenoemgalie - masivní infiltrace dřeně, B symptomy ( horečky a pocení) - start terapie imbruvica 11.5.2017,   s ohledem na nachĺazení a recid.infekce ponechávám dávku 2tbl/den - efekt parciální remise dle CT 11/2017 max velikost uzlin 17mm - trvá parciální remise 19.9.18   10/2018 CT za hospitaizace další regrese lymfadenopatie, hodnotím dle   velikosti uzin jako parciální remise ( max velikost 15x18mm) - 14.11. 2019 trvá parciální remise, pokračování tepraie ibrutinibem - 2/2020 - mírný pokles Trc,. anamnesticky teploty - 13/3/2020 PET/CT zmnožené uzliny, susp ca plic, došetřováno, dále ale   vyloučeno, imbruvica byla vysazena, tedy vs při pneumonii, regrese   infiltrátu, PET/CT bez zvýšené aktivity jen lehká progrese uzlin, na CT   5/2020 opět lehké zmenšení uzlin tedy trvá PR, při vysazení imbruvica B   symptomy - od 28/5/2020 pokračováno v terapii imbruvica - 2.7.20 klinicky bez obtíží, bez teplot, pokračujeme v terapii   imbruvica,. klinicky paricální remise - 31.3.22 trvá klinická CR, pokračujeme - 3.6.22 trombocytopenie Rai IV A, v dif dg progrese/NÚ Imbruvica -   snížena dávka s následnou zjevnou prog ...
# (0.19227505763348415, 26053651, 4495603, 2127268, datetime.date(2023, 2, 16), datetime.datetime(1900, 1, 1, 11, 11), 41742, '', 'C911 ', 'venetoklax                                                  ', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'Počátek vyšetření: 16.02.2023 08:22 Odběr:16.02.2023 07:47 WBC 6.9 10^9/l RBC 4.98 10^12/l HGB 133 g/l HCT 0.4 l/l MCV 80.9 fL PLT 175 10^9/l MCH 26.7 pg MCHC 330 g/l MPV 8.4 fl RDW 14.7 % NEU% 68.6 % LYM% 21 % MON% 10 % EOS% 0 % BAS% 0.4 % NEU 4.73 10^9/l LYM 1.45 10^9/l MONO 0.69 10^9/l EOS 0 10^9/l BASO 0.03 10^9/l NRBC 0 10^9/l NRBC/WBC 0 /100WBC Odběr:16.02.2023 07:47 Urea S-Urea 5.3 mmol/l (2.8-8.1) Kreat. S-Kreatinin 71 umol/l (62-106) CKD-EPI CKD-EPI Krea 1.65 ml/s/1.73m2 (1-2.4) Na S-Na 137 mmol/l (136-145) K S-K 4.4 mmol/l (3.5-5.1) Cl S-Cl 102 mmol/l (98-107) Ca S-Ca 2.40 mmol/l (2.15-2.55) P S-P 1.03 mmol/l (0.81-1.45) Mg S-Mg 0.85 mmol/l (0.71-0.94) Bi-celk. S-Bilirubin celk 4.9 umol/l (2-21) ALT S-ALT 0.43 ukat/l (0.17-0.83) AST S-AST 0.34 ukat/l (0.17-0.85) GGT S-GMT 0.69 ukat/l (0.17-1.19) ALP S-ALP 2.51 ukat/l (0.67-2.15) Glukóza S-Glukosa 9.3 mmol/l (3.9-5.6) CRP S-CRP 5.2 mg/l (0-5) Materiál S/P: :plazma S: celkový stav dobrý teplota nebyla, není krvácení pocení není nejsou B symptomy O:ECOG 1 du čistá, jazyk vlhký oběhově komp, orientován, eupnoe, uzliny na krku nehmatné, podpaží nehmatné, třísla nehmatné, břicho vzhledem k habitu hůře prohmatné, nebolestivé, játra nehmatám, slezinu nehmatám dkk chron změny bez otoků ~do~C911 Chronická B-lymfocytární leukemie, dg. z flow 15.4.2016~df~ - RAI IVA, Binet C ( lymfocyotza, trombocytopenie, hraniční anemie, bez   hmatné periferní lyfadenopatie) - nová dg, odběr prognostických faktorů na JIP IHOK 15.4.16, není AIHA - nález v likvoru také pozitivní, ale příměs krve, neuropatie a třes   při DM, t.č. zcela bez neurologické symptomatologie, etiolgoie jen   infekce, neprováděno MR mozku, infiltrace není pravdpěodobná - 1 linie léčby 2x FCR 19.4. a 18.5.2016 efekt SD - 4/2016 nově mutace TP 53 a delece 17p, IgVH nemutovaný, CD 38  negativní   cytogenetika delece 17p  77% - komplikováno recidivující bronchopneumonií - 2. linie  13.7.2016  1. RCD - 3. linie 10.8.2016 alemtuzumab, efekt 5.9.16 jako PR ( vstupně 4/2016   trombocytopenie, anemie, splenomegalie, lymfadenopatie v oblati mesenteria   a retroperitoenea dle sonografie, teploty, váhový úbytek) - 13.10.2016 krevní obraz zcela v normně, dle sonografie břicha   splenomegalie 19cm, četné uzliny paraaortálně 25mm   efekt hodnotím jako PR 13.10.2016 po aplikaci 4 týdnů - nyní observace, ukončeno pro listeriozovou sepsi 7.9.2016 - progrese 23.3.2017, RAi IVA, trombocytopenie   sonograficky lehká splenoemgalie - masivní infiltrace dřeně, B symptomy ( horečky a pocení) - start terapie imbruvica 11.5.2017,   s ohledem na nachĺazení a recid.infekce ponechávám dávku 2tbl/den - efekt parciální remise dle CT 11/2017 max velikost uzlin 17mm - trvá parciální remise 19.9.18   10/2018 CT za hospitaizace další regrese lymfadenopatie, hodnotím dle   velikosti uzin jako parciální remise ( max velikost 15x18mm) - 14.11. 2019 trvá parciální remise, pokračování tepraie ibrutinibem - 2/2020 - mírný pokles Trc,. anamnesticky teploty - 13/3/2020 PET/CT zmnožené uzliny, susp ca plic, došetřováno, dále ale   vyloučeno, imbruvica byla vysazena, tedy vs při pneumonii, regrese   infiltrátu, PET/CT bez zvýšené aktivity jen lehká progrese uzlin, na CT   5/2020 opět lehké zmenšení uzlin tedy trvá PR, při vysazení imbruvica B   symptomy - od 28/5/2020 pokračováno v terapii imbruvica - 2.7.20 klinicky bez obtíží, bez teplot, pokračujeme v terapii   imbruvica,. klinicky paricální remise - 31.3.22 trvá klinická CR, pokračujeme - 3.6.22 trombocytopenie Rai IV A, v dif dg progrese/NÚ Imbruvica -   snížena dávka s následnou zjevnou progresí lymfadenopatie - dle CT 7.9.22 ve zlíně je progrese lymfadenopatie, max velikost uzlin je   v malé pánvi podél cévního svazku oboustranně, vpravo 79mm s ...
# (0.1805003386549406, 26498142, 4495603, 2127268, datetime.date(2023, 7, 20), datetime.datetime(1900, 1, 1, 9, 19), 41742, '', 'C911 ', 'venclyxto                                                   ', 'Chronická lymfocytická leukemie z B-buněk                   ', '', 'Počátek vyšetření: 20.07.2023 09:09 Odběr:20.07.2023 07:28 WBC 5.260 10^9/l RBC 4.77 10^12/l HGB 130.0 g/l HCT 0.400 l/l MCV 83.9 fL PLT 136.0 10^9/l MCH 27.3 pg MCHC 325.0 g/l MPV 8.80 fl RDW 13.6 % NEU% 67.70 % LYM% 22.80 % MON% 9.30 % EOS% 0.00 % BAS% 0.20 % NEU 3.560 10^9/l LYM 1.200 10^9/l MONO 0.490 10^9/l EOS 0.000 10^9/l BASO 0.010 10^9/l NRBC 0.00 10^9/l NRBC/WBC 0.00 /100WBC B_OKB_ARP Biochemie/Imunologie Odběr:20.07.2023 07:28 Urea S-Urea 4.3 mmol/l (2.8-8.1) Kreat. S-Kreatinin 69 umol/l (62-106) CKD-EPI CKD-EPI Krea 1.66 ml/s/1.73m2 (1-2.4) KM S-Kys.močová 151 umol/l (202-417) Na S-Na 139 mmol/l (136-145) K S-K 5.2 mmol/l (3.5-5.1) Cl S-Cl 105 mmol/l (98-107) Ca S-Ca 2.28 mmol/l (2.15-2.55) P S-P 1.21 mmol/l (0.81-1.45) Mg S-Mg 0.89 mmol/l (0.71-0.94) Bi-celk. S-Bilirubin celk 6.0 umol/l (2-21) ALT S-ALT 0.34 ukat/l (0.17-0.83) AST S-AST 0.28 ukat/l (0.17-0.85) GGT S-GMT 0.51 ukat/l (0.17-1.19) ALP S-ALP 2.43 ukat/l (0.67-2.15) LD S-LD 3.38 ukat/l (2.25-3.75) Glukóza S-Glukosa 7.6 mmol/l (3.9-5.6) CRP S-CRP 9.0 mg/l (0-5) * 11.7.2023 dle CT: uzliny povšechně do 15mm, slezina   158x75mm stacionární S: nemá žádné potíže, cítí se dobře, bez teplot, nechlazen není, venclyxto snáší dobře. Bez B symptomů. O:ECOG 1 du čistá, jazyk vlhký oběhově komp, orientován, eupnoe, uzliny na krku nehmatné, podpaží nehmatné, třísla nehmatné, břicho vzhledem k habitu hůře prohmatné, nebolestivé, játra nehmatám, slezinu nehmatám dkk chron změny bez otoků ~do~C911 Chronická B-lymfocytární leukemie, dg. z flow 15.4.2016~df~ - RAI IVA, Binet C ( lymfocyotza, trombocytopenie, hraniční anemie, bez   hmatné periferní lyfadenopatie) - nová dg, odběr prognostických faktorů na JIP IHOK 15.4.16, není AIHA - nález v likvoru také pozitivní, ale příměs krve, neuropatie a třes   při DM, t.č. zcela bez neurologické symptomatologie, etiolgoie jen   infekce, neprováděno MR mozku, infiltrace není pravdpěodobná - 1 linie léčby 2x FCR 19.4. a 18.5.2016 efekt SD - 4/2016 nově mutace TP 53 a delece 17p, IgVH nemutovaný, CD 38  negativní   cytogenetika delece 17p  77% - komplikováno recidivující bronchopneumonií - 2. linie  13.7.2016  1. RCD - 3. linie 10.8.2016 alemtuzumab, efekt 5.9.16 jako PR ( vstupně 4/2016   trombocytopenie, anemie, splenomegalie, lymfadenopatie v oblati mesenteria   a retroperitoenea dle sonografie, teploty, váhový úbytek) - 13.10.2016 krevní obraz zcela v normně, dle sonografie břicha   splenomegalie 19cm, četné uzliny paraaortálně 25mm   efekt hodnotím jako PR 13.10.2016 po aplikaci 4 týdnů - nyní observace, ukončeno pro listeriozovou sepsi 7.9.2016 - progrese 23.3.2017, RAi IVA, trombocytopenie   sonograficky lehká splenoemgalie - masivní infiltrace dřeně, B symptomy ( horečky a pocení) - start terapie imbruvica 11.5.2017,   s ohledem na nachĺazení a recid.infekce ponechávám dávku 2tbl/den - efekt parciální remise dle CT 11/2017 max velikost uzlin 17mm - trvá parciální remise 19.9.18   10/2018 CT za hospitaizace další regrese lymfadenopatie, hodnotím dle   velikosti uzin jako parciální remise ( max velikost 15x18mm) - 14.11. 2019 trvá parciální remise, pokračování tepraie ibrutinibem - 2/2020 - mírný pokles Trc,. anamnesticky teploty - 13/3/2020 PET/CT zmnožené uzliny, susp ca plic, došetřováno, dále ale   vyloučeno, imbruvica byla vysazena, tedy vs při pneumonii, regrese   infiltrátu, PET/CT bez zvýšené aktivity jen lehká progrese uzlin, na CT   5/2020 opět lehké zmenšení uzlin tedy trvá PR, při vysazení imbruvica B   symptomy - od 28/5/2020 pokračováno v terapii imbruvica - 2.7.20 klinicky bez obtíží, bez teplot, pokračujeme v terapii   imbruvica,. klinicky paricální remise - 31.3.22 trvá klinická CR, pokračujeme - 3.6.22 trombocytopenie Rai IV A, v dif dg progrese/NÚ ...
